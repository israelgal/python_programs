# %%
import pylab as pl

x= [.103,.201,.300,.409,.504,.601,.701,.806,.901,1.003,1.102,1.197,1.299,1.404,1.498,1.603,1.699,1.805,1.906,2.000]
y= [0.042,0.087,-0.127,-0.170,-0.213,-0.252,-0.295,-0.339,-0.380,-0.430,-0.470,-0.509,-0.556,-0.599,-0.637,-0.683,-0.724,-0.769,-0.813,-0.854]

print(len(y))
pl.plot(x, y, 'bo')
pl.xlabel('Corriente en Amperes [A]')
pl.ylabel('Diferencia de masa [gr]')
# Guarda la grafica en formato png
pl.savefig('corrientevsmasa.png')
pl.show()
# Out:
# 20

# %%
import pylab as pl

a=[.103,.201,.300,.409,.504,.601,.701,.806,.901,1.003,1.102,1.197,1.299,1.404,1.498,1.603,1.699,1.805,1.906,2.000]
b=[0.4116,0.8526,1.244,1.666,2.0874,2.4696,2.891,3.322,3.724,4.214,4.606,4.9882,5.448,5.8702,6.2426,6.6934,7.0952,7.5362,7.9674,8.3692]
pl.plot(a, b, 'bo')
pl.xlabel('Corriente en Amperes en[A]')
pl.ylabel('Magnitud de la fuerza en [mN]')
# Guarda la grafica en formato png
pl.savefig('corrientevsfuerza.png')
pl.show()

# %%
import pylab as pl

c=[0.92,1.2,2.2,2.8,3.2,3.7,4.2]
d=[-0.086,-0.154,-0.282,-0.369,-0.422,-0.474,-0.559]

pl.plot(c, d, 'bo')
pl.xlabel('Longitud del cable en [cm]')
pl.ylabel('Diferencia de masa en [gr]')
# Guarda la grafica en formato png
pl.savefig('longitudvsmasa.png')
pl.show()

# %%
import pylab as pl

k=[0.92,1.2,2.2,2.8,3.2,3.7,4.2]
l=[0.842,1.509,2.7636,3.6162,4.1356,4.6452,5.4782]

pl.plot(k, l, 'bo')
pl.xlabel('Longitud del cable en [cm]')
pl.ylabel('Magnitud de la fuerza en [mN]')
# Guarda la grafica en formato png
pl.savefig('longitudvsfuerza.png')
pl.show()
